# %%
import pandas as pd

git_log_raw = pd.read_csv(
    "../../buschmais-spring-petclinic/git_log_machine.log",
    sep='\u0012',
    names= ["raw"])
git_log_raw.head()
# Out:
#                                               raw
# 0  521d01db950e357cf81ef78c50daf290e92b309c 1 1 1
# 1                              author Costin Leau
# 2                  author-mail <cleau@vmware.com>
# 3                          author-time 1259174752
# 4                                 author-tz +0000

# %%
git_log_raw['type'] = git_log_raw.raw.str.split(" ", n=1).str[0]
git_log_raw.melt
# Out:
#                                                     raw  \
# 0        521d01db950e357cf81ef78c50daf290e92b309c 1 1 1
# 1                                    author Costin Leau
# 2                        author-mail <cleau@vmware.com>
# 3                                author-time 1259174752
# 4                                       author-tz +0000
# 5                                committer Michael Isvy
# 6                     committer-mail <misvy@vmware.com>
# 7                             committer-time 1357722797
# 8                                    committer-tz +0800
# 9                                      summary SPR-6447
# 10                                     filename pom.xml
# 11             \t<?xml version="1.0" encoding="UTF-8"?>
# 12       09ed33a5fc01209b4190c74f405b2b1e523b739c 2 2 5
# 13                                   author Antoine Rey
# 14                    author-mail <antoine.rey@free.fr>
# 15                               author-time 1444980786
# 16                                      author-tz +0200
# 17                                committer Antoine Rey
# 18                 committer-mail <antoine.rey@free.fr>
# 19                            committer-time 1444980808
# 20                                   committer-tz +0200
# 21          summary #96 Reformat code with EditorConfig
# 22    previous 1aef94d6a86634f810b1eae448d4e2594eac5...
# 23                                     filename pom.xml
# 24    \t<project xmlns:xsi="http://www.w3.org/2001/X...
# 25         09ed33a5fc01209b4190c74f405b2b1e523b739c 3 3
# 26    \t         xsi:schemaLocation="http://maven.ap...
# 27         09ed33a5fc01209b4190c74f405b2b1e523b739c 4 4
# 28             \t    <modelVersion>4.0.0</modelVersion>
# 29         09ed33a5fc01209b4190c74f405b2b1e523b739c 5 5
# ...                                                 ...
# 1446                               \t        </profile>
# 1447  540d31ed217c8ab36dcceda0ee72da7009c72ad7 419 5...
# 1448                                   \t   </profiles>
# 1449  57e17d32b285d63c96747e5fed059ef1ea4cb529 226 5...
# 1450                                author Keith Donald
# 1451                   author-mail <kdonald@vmware.com>
# 1452                             author-time 1261075904
# 1453                                    author-tz +0000
# 1454                             committer Michael Isvy
# 1455                  committer-mail <misvy@vmware.com>
# 1456                          committer-time 1357722804
# 1457                                 committer-tz +0800
# 1458         summary finally got rid of commons logging
# 1459  previous 905d9824b012ee6eceb8305cd15d521c3b4d1...
# 1460                                   filename pom.xml
# 1461  09ed33a5fc01209b4190c74f405b2b1e523b739c 406 5...
# 1462                     \t    <url>demopetclinic</url>
# 1463  1741e85044b6378ec5d16f49ac9f85d918c2dd2a 488 5...
# 1464                                author Michael Isvy
# 1465                     author-mail <misvy@vmware.com>
# 1466                             author-time 1366851620
# 1467                                    author-tz +0800
# 1468                             committer Michael Isvy
# 1469                  committer-mail <misvy@vmware.com>
# 1470                          committer-time 1366851620
# 1471                                 committer-tz +0800
# 1472  summary migrated to Hibernate-Validator 5.0.0....
# 1473  previous 94109017dec44bb34ea7b2034d0ef6ba00760...
# 1474                                   filename pom.xml
# 1475                                       \t</project>
#
#                                           type
# 0     521d01db950e357cf81ef78c50daf290e92b309c
# 1                                       author
# 2                                  author-mail
# 3                                  author-time
# 4                                    author-tz
# 5                                    committer
# 6                               committer-mail
# 7                               committer-time
# 8                                 committer-tz
# 9                                      summary
# 10                                    filename
# 11                                     \t<?xml
# 12    09ed33a5fc01209b4190c74f405b2b1e523b739c
# 13                                      author
# 14                                 author-mail
# 15                                 author-time
# 16                                   author-tz
# 17                                   committer
# 18                              committer-mail
# 19                              committer-time
# 20                                committer-tz
# 21                                     summary
# 22                                    previous
# 23                                    filename
# 24                                  \t<project
# 25    09ed33a5fc01209b4190c74f405b2b1e523b739c
# 26                                          \t
# 27    09ed33a5fc01209b4190c74f405b2b1e523b739c
# 28                                          \t
# 29    09ed33a5fc01209b4190c74f405b2b1e523b739c
# ...                                        ...
# 1446                                        \t
# 1447  540d31ed217c8ab36dcceda0ee72da7009c72ad7
# 1448                                        \t
# 1449  57e17d32b285d63c96747e5fed059ef1ea4cb529
# 1450                                    author
# 1451                               author-mail
# 1452                               author-time
# 1453                                 author-tz
# 1454                                 committer
# 1455                            committer-mail
# 1456                            committer-time
# 1457                              committer-tz
# 1458                                   summary
# 1459                                  previous
# 1460                                  filename
# 1461  09ed33a5fc01209b4190c74f405b2b1e523b739c
# 1462                                        \t
# 1463  1741e85044b6378ec5d16f49ac9f85d918c2dd2a
# 1464                                    author
# 1465                               author-mail
# 1466                               author-time
# 1467                                 author-tz
# 1468                                 committer
# 1469                            committer-mail
# 1470                            committer-time
# 1471                              committer-tz
# 1472                                   summary
# 1473                                  previous
# 1474                                  filename
# 1475                              \t</project>
#
# [1476 rows x 2 columns]
