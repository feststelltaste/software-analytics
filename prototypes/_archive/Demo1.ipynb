# %% [markdown]
# # Demo for Neo4j Online Meetup
#
# Hello
# * Guys
# * Gals
#
# out there!

# %%
import pandas as pd
coverage = pd.read_csv("../input/spring-petclinic/jacoco.csv")[['PACKAGE','LINE_COVERED']]
coverage.head()
# Out:
#                                        PACKAGE  LINE_COVERED
# 0        org.springframework.samples.petclinic            24
# 1  org.springframework.samples.petclinic.model             4
# 2  org.springframework.samples.petclinic.model             1
# 3  org.springframework.samples.petclinic.model             1
# 4  org.springframework.samples.petclinic.model             0

# %%
# %matplotlib inline
coverage.groupby('PACKAGE').sum().plot(kind='barh')
