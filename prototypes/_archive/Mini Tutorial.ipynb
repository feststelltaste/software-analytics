# %%
import pandas as pd
pd.read_csv("http://172.16.7.54/git_oneline_numstat.log")
# Out:
#                                    1\t1\tdocs/README.md
# 0                                 76\t0\tdocs/README.md
# 1                    290\t0\tdocs/assets/css/style.scss
# 2     -\t-\tdocs/documentation/images/class-diagram.png
# 3                1224\t0\tdocs/documentation/index.html
# 4                    -\t-\tdocs/documentation/index.pdf
# 5               155\t0\tdocs/reports/css/maven-base.css
# 6              141\t0\tdocs/reports/css/maven-theme.css
# 7                      7\t0\tdocs/reports/css/print.css
# 8                       1\t0\tdocs/reports/css/site.css
# 9                   -\t-\tdocs/reports/images/close.gif
# 10              -\t-\tdocs/reports/images/collapsed.gif
# 11               -\t-\tdocs/reports/images/expanded.gif
# 12               -\t-\tdocs/reports/images/external.png
# 13         -\t-\tdocs/reports/images/icon_error_sml.gif
# 14          -\t-\tdocs/reports/images/icon_info_sml.gif
# 15       -\t-\tdocs/reports/images/icon_success_sml.gif
# ...

# %%
import pandas as pd
pd.read_csv("https://raw.githubusercontent.com/feststelltaste/software-analytics/master/notebooks/input/spring-petclinic/jacoco.csv")
# Out:
#                      GROUP                                            PACKAGE  \
# 0   JaCoCo Coverage Report              org.springframework.samples.petclinic
# 1   JaCoCo Coverage Report        org.springframework.samples.petclinic.model
# 2   JaCoCo Coverage Report        org.springframework.samples.petclinic.model
# 3   JaCoCo Coverage Report        org.springframework.samples.petclinic.model
# 4   JaCoCo Coverage Report        org.springframework.samples.petclinic.model
# 5   JaCoCo Coverage Report        org.springframework.samples.petclinic.model
# 6   JaCoCo Coverage Report        org.springframework.samples.petclinic.model
# 7   JaCoCo Coverage Report        org.springframework.samples.petclinic.model
# 8   JaCoCo Coverage Report        org.springframework.samples.petclinic.model
# 9   JaCoCo Coverage Report        org.springframework.samples.petclinic.model
# 10  JaCoCo Coverage Report        org.springframework.samples.petclinic.model
# ...

# %%
URL="https://en.wikipedia.org/wiki/All-time_table_of_the_FIFA_World_Cup"
wc_table = pd.read_html(URL, header=0, index_col=0)[0]
wc_table.head()
# Out:
#            Team  Part's  Pld   W   D   L   GF   GA   GD  Pts  Avg Pts  \
# Pos
# 1        Brazil      20  104  70  17  17  221  102  119  227     2.18
# 2    Germany[1]      18  106  66  20  20  224  121  103  218     2.06
# 3         Italy      18   83  45  21  17  128   77   51  156     1.88
# 4     Argentina      16   77  42  14  21  131   84   47  140     1.82
# 5         Spain      14   59  29  12  18   92   66   26   99     1.68
#
#              Best finish
# Pos
# 1    1 !Winner (5 Times)
# 2    1 !Winner (4 Times)
# 3    1 !Winner (4 Times)
# 4    1 !Winner (2 Times)
# 5     1 !Winner (1 Time)

# %%
wc_table[wc_table['W'] == wc_table['W'].max()]
# Out:
#        Team  Part's  Pld   W   D   L   GF   GA   GD  Pts  Avg Pts  \
# Pos
# 1    Brazil      20  104  70  17  17  221  102  119  227     2.18
#
#              Best finish
# Pos
# 1    1 !Winner (5 Times)
