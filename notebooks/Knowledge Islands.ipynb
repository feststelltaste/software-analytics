# %% [markdown]
# TLDR; I show how you can visualize the knowledge about source code by mining a version control system.
#
# # Introduction
# In software development, it's all about the knowledge &ndash; both technical and the business domain. But we software developers transfer only a small part of this knowledge into code. So code alone isn't sufficient to get a glimpse of the greater picture and the interrelations of all the different concepts. There will be always developers that know more about some concept as laid down in the source code. It's important to make sure that this knowledge is distributed over more than one head.
#
# It's possible to estimate this knowledge distribution by analyzing the version control system. We can use active changes in the code as proxy for "someone know what he does", because otherwise, he wouldn't be able to contribute code. To find spots where the knowledge about the code could be improved, we can identify areas in the code that are possibly known by only one developer. This gives you a hint where you should start some pair programming of a invest in redocumentation.
#
# We can approximate the knowledge distribution by counting the number of additions per file that each developer contributed to a software system.
#
# I'll show you step by step how you can do this by using Python and [Pandas](http://pandas.pydata.org/).
#
#
# Attribution: The work is heavily inspired by Adam Tornhill's book ["Your Code as a Crime Scene"](https://pragprog.com/book/atcrime/your-code-as-a-crime-scene), who did a similar analysis called "knowledge map".

# %% [markdown]
# # Import history
# For this analysis, you need a log from your Git repository. In this example, we analyze a fork of the Spring PetClinic project. To avoid some noise, we add some paramaters (<tt>--no-merges</tt> and <tt>--no-renames</tt>
#
# ```bash
# git log --no-merges --no-renames --numstat --pretty=format:"%x09%x09%x09%aN"
# ```
#
# We read the log output into a Pandas' <tt>DataFrame</tt> by using the method describe in this [blog post](https://www.feststelltaste.de/reading-a-git-repos-commit-history-with-pandas-efficiently/) slightly modified (because we need less data):

# %%
import git
from io import StringIO
import pandas as pd

# connect to repo
git_bin = git.Repo("../../buschmais-spring-petclinic/").git

# execute log command
git_log = git_bin.execute('git log --no-merges --no-renames --numstat --pretty=format:"%x09%x09%x09%aN" -- *.java')

# read in the log
git_log = pd.read_csv(StringIO(git_log), sep="\x09", header=None, names=['additions', 'deletions', 'path','author'])

# convert to DataFrame
commit_data = git_log[['additions', 'deletions', 'path']].join(git_log[['author']].fillna(method='ffill')).dropna()
commit_data.head()
# Out:
#    additions  deletions                                               path  \
# 1        4.0        5.0  src/test/java/org/springframework/samples/petc...
# 2       25.0        7.0  src/test/java/org/springframework/samples/petc...
# 3       21.0        9.0  src/test/java/org/springframework/samples/petc...
# 4       23.0        3.0  src/test/java/org/springframework/samples/petc...
# 5       10.0        6.0  src/test/java/org/springframework/samples/petc...
#
#         author
# 1  Antoine Rey
# 2  Antoine Rey
# 3  Antoine Rey
# 4  Antoine Rey
# 5  Antoine Rey

# %% [markdown]
# # Getting data that matters
#
# In this example, we are only interested in Java source code files that still exist in the software project
#
# We can retrieve the existing Java source code files by using Git's <tt>ls-files</tt> combined with a filter for the Java source code file extension. The command will return a plain text string that we split by the line ending to get a list of files. Because we want to combine this information with the other above, we put it into a <tt>DataFrame</tt> with the column name <tt>path</tt>.

# %%
java_files = pd.DataFrame(git_bin.execute("git ls-files -- *.java ").split("\n"), columns=['path'])
java_files.head()
# Out:
#                                                 path
# 0  src/main/java/org/springframework/samples/petc...
# 1  src/main/java/org/springframework/samples/petc...
# 2  src/main/java/org/springframework/samples/petc...
# 3  src/main/java/org/springframework/samples/petc...
# 4  src/main/java/org/springframework/samples/petc...

# %% [markdown]
# The next step is to combined the <tt>commit_data</tt> with the <tt>java_files</tt> information by using Pandas' <tt>merge</tt> function. By default, <tt>merge</tt> will
# - combine the data by the columns with the same name in each <tt>DataFrame</tt>
# - only leave those entries that have the same value (using an "inner join").
#
# In plain English, <tt>merge</tt> will only leave the still existing Java source code files in the <tt>DataFrame</tt>. This is exactly what we need.

# %%
contributions = pd.merge(commit_data, java_files)
contributions.head()
# Out:
#    additions  deletions                                               path  \
# 0        4.0        5.0  src/test/java/org/springframework/samples/petc...
# 1       53.0        0.0  src/test/java/org/springframework/samples/petc...
# 2       25.0        7.0  src/test/java/org/springframework/samples/petc...
# 3      167.0        0.0  src/test/java/org/springframework/samples/petc...
# 4       21.0        9.0  src/test/java/org/springframework/samples/petc...
#
#         author
# 0  Antoine Rey
# 1    Colin But
# 2  Antoine Rey
# 3    Colin But
# 4  Antoine Rey

# %% [markdown]
# We can now convert some columns to their correct data types. The columns <tt>additions</tt> and <tt>deletions</tt> columns are representing the added or deleted lines of code respectively. We have to convert them accordingly.

# %%
contributions['additions'] = pd.to_numeric(contributions['additions'])
contributions['deletions'] = pd.to_numeric(contributions['deletions'])
contributions.head()
# Out:
#    additions  deletions                                               path  \
# 0        4.0        5.0  src/test/java/org/springframework/samples/petc...
# 1       53.0        0.0  src/test/java/org/springframework/samples/petc...
# 2       25.0        7.0  src/test/java/org/springframework/samples/petc...
# 3      167.0        0.0  src/test/java/org/springframework/samples/petc...
# 4       21.0        9.0  src/test/java/org/springframework/samples/petc...
#
#         author
# 0  Antoine Rey
# 1    Colin But
# 2  Antoine Rey
# 3    Colin But
# 4  Antoine Rey

# %% [markdown]
# We want to estimate the knowledge about code as the proportion of additions to the whole source code file. This means we need to calculate the relative amount of added lines for each developer. To be able to do this, we have to know the sum of all additions for a file.
#
# Additionally, we calculate is for deletions, to easily get the number of lines for each code.
#
# We have to normalize the <tt>additions</tt> column to be able to calculate the relative proportion that each author contributed to the source code. We use an additional <tt>DataFrame</tt> to do that (I think there is a more elegant way to do this).

# %%
additions_sum = contributions.groupby('path').sum()[['additions', 'deletions']].reset_index()
additions_sum.head()
# Out:
#                                                 path  additions  deletions
# 0  src/main/java/org/springframework/samples/petc...      111.0        0.0
# 1  src/main/java/org/springframework/samples/petc...       70.0       23.0
# 2  src/main/java/org/springframework/samples/petc...       67.0       19.0
# 3  src/main/java/org/springframework/samples/petc...      290.0      137.0
# 4  src/main/java/org/springframework/samples/petc...       79.0       23.0

# %% [markdown]
# We also want to have an indicator about the quantity of the knowledge. This can be easily achieve if we calculate the lines of code for each files, which is a simple substraction of the deletions form the additions:

# %%
additions_sum['length'] = additions_sum['additions'] - additions_sum['deletions']
additions_sum.head()
# Out:
#                                                 path  additions  deletions  \
# 0  src/main/java/org/springframework/samples/petc...      111.0        0.0
# 1  src/main/java/org/springframework/samples/petc...       70.0       23.0
# 2  src/main/java/org/springframework/samples/petc...       67.0       19.0
# 3  src/main/java/org/springframework/samples/petc...      290.0      137.0
# 4  src/main/java/org/springframework/samples/petc...       79.0       23.0
#
#    length
# 0   111.0
# 1    47.0
# 2    48.0
# 3   153.0
# 4    56.0

# %% [markdown]
# # Identify knowledge hotspots

# %% [markdown]
# If we are here, we also retrieve the lines of code for the existing files by simply counting the lines for each file. We do this by a simple function tha reads in the whole file and couting the lines. It's not elegant, but it works pretty good.
#
# We need that information for visualizing "knowledge islands" later on.

# %% [markdown]
# And combine it analog as above.

# %%
contributions_norm = pd.merge(
    contributions, 
    additions_sum, 
    left_on='path', 
    right_on='path', 
    suffixes=['', '_sum'])
contributions_norm.head()
# Out:
#    additions  deletions                                               path  \
# 0        4.0        5.0  src/test/java/org/springframework/samples/petc...
# 1       53.0        0.0  src/test/java/org/springframework/samples/petc...
# 2       25.0        7.0  src/test/java/org/springframework/samples/petc...
# 3      167.0        0.0  src/test/java/org/springframework/samples/petc...
# 4       21.0        9.0  src/test/java/org/springframework/samples/petc...
#
#         author  additions_sum  deletions_sum  length
# 0  Antoine Rey           57.0            5.0    52.0
# 1    Colin But           57.0            5.0    52.0
# 2  Antoine Rey          192.0            7.0   185.0
# 3    Colin But          192.0            7.0   185.0
# 4  Antoine Rey          134.0            9.0   125.0

# %%
grouped_commits = contributions_norm.groupby(
    ['path']).sum()
grouped_commits.head()
# Out:
#                                                     additions  deletions  \
# path
# src/main/java/org/springframework/samples/petcl...      111.0        0.0
# src/main/java/org/springframework/samples/petcl...       70.0       23.0
# src/main/java/org/springframework/samples/petcl...       67.0       19.0
# src/main/java/org/springframework/samples/petcl...      290.0      137.0
# src/main/java/org/springframework/samples/petcl...       79.0       23.0
#
#                                                     additions_sum  \
# path
# src/main/java/org/springframework/samples/petcl...          111.0
# src/main/java/org/springframework/samples/petcl...          560.0
# src/main/java/org/springframework/samples/petcl...          268.0
# src/main/java/org/springframework/samples/petcl...         1740.0
# src/main/java/org/springframework/samples/petcl...          316.0
#
#                                                     deletions_sum  length
# path
# src/main/java/org/springframework/samples/petcl...            0.0   111.0
# src/main/java/org/springframework/samples/petcl...          184.0   376.0
# src/main/java/org/springframework/samples/petcl...           76.0   192.0
# src/main/java/org/springframework/samples/petcl...          822.0   918.0
# src/main/java/org/springframework/samples/petcl...           92.0   224.0

# %%
grouped_commits = contributions_norm.groupby(
    ['path', 'author']).agg(
    {'additions' : 'sum',
     'additions_sum' : 'first',
     'length' : 'first'})
grouped_commits
# Out:
#                                                                       additions  \
# path                                               author
# src/main/java/org/springframework/samples/petcl... Antoine Rey            111.0
# src/main/java/org/springframework/samples/petcl... Antoine Rey              3.0
#                                                    Faisal Hameed            1.0
#                                                    Gordon Dickens          14.0
#                                                    Michael Isvy            51.0
#                                                    boly38                   1.0
# src/main/java/org/springframework/samples/petcl... Antoine Rey              3.0
#                                                    Gordon Dickens          15.0
#                                                    Michael Isvy            49.0
# src/main/java/org/springframework/samples/petcl... Antoine Rey             14.0
#                                                    Gordon Dickens         112.0
#                                                    Michael Isvy           164.0
# src/main/java/org/springframework/samples/petcl... Gordon Dickens          20.0
#                                                    Michael Isvy            59.0
# src/main/java/org/springframework/samples/petcl... Antoine Rey             17.0
#                                                    Gordon Dickens          64.0
#                                                    Michael Isvy           127.0
# src/main/java/org/springframework/samples/petcl... Antoine Rey              1.0
#                                                    Gordon Dickens           2.0
#                                                    Michael Isvy            28.0
# src/main/java/org/springframework/samples/petcl... Gordon Dickens           3.0
#                                                    Michael Isvy            29.0
# src/main/java/org/springframework/samples/petcl... Antoine Rey              7.0
#                                                    Gordon Dickens          31.0
#                                                    Michael Isvy            92.0
# src/main/java/org/springframework/samples/petcl... Antoine Rey              1.0
#                                                    Gordon Dickens          12.0
#                                                    Michael Isvy            49.0
#                                                    Tomas Repel              0.0
# src/main/java/org/springframework/samples/petcl... Gordon Dickens          87.0
# ...                                                                         ...
# src/main/java/org/springframework/samples/petcl... Gordon Dickens          36.0
#                                                    Michael Isvy           144.0
#                                                    Rossen Stoyanchev        4.0
# src/main/java/org/springframework/samples/petcl... Antoine Rey              0.0
#                                                    Costin Leau              8.0
# src/test/java/org/springframework/samples/petcl... Antoine Rey             16.0
#                                                    Michael Isvy            60.0
# src/test/java/org/springframework/samples/petcl... Antoine Rey             91.0
#                                                    Attilio                 10.0
#                                                    Faisal Hameed            1.0
#                                                    Martin Klose             1.0
#                                                    Michael Isvy           285.0
# src/test/java/org/springframework/samples/petcl... Antoine Rey              2.0
#                                                    Michael Isvy            37.0
# src/test/java/org/springframework/samples/petcl... Antoine Rey              3.0
#                                                    Michael Isvy            30.0
# src/test/java/org/springframework/samples/petcl... Antoine Rey              4.0
#                                                    Michael Isvy            20.0
# src/test/java/org/springframework/samples/petcl... Antoine Rey              4.0
#                                                    Colin But               53.0
# src/test/java/org/springframework/samples/petcl... Antoine Rey             25.0
#                                                    Colin But              167.0
# src/test/java/org/springframework/samples/petcl... Antoine Rey             21.0
#                                                    Colin But              113.0
# src/test/java/org/springframework/samples/petcl... Colin But               76.0
# src/test/java/org/springframework/samples/petcl... Antoine Rey             41.0
#                                                    Colin But               22.0
#                                                    Michael Isvy            53.0
# src/test/java/org/springframework/samples/petcl... Antoine Rey             10.0
#                                                    Colin But               79.0
#
#                                                                       additions_sum  \
# path                                               author
# src/main/java/org/springframework/samples/petcl... Antoine Rey                111.0
# src/main/java/org/springframework/samples/petcl... Antoine Rey                 70.0
#                                                    Faisal Hameed               70.0
#                                                    Gordon Dickens              70.0
#                                                    Michael Isvy                70.0
#                                                    boly38                      70.0
# src/main/java/org/springframework/samples/petcl... Antoine Rey                 67.0
#                                                    Gordon Dickens              67.0
#                                                    Michael Isvy                67.0
# src/main/java/org/springframework/samples/petcl... Antoine Rey                290.0
#                                                    Gordon Dickens             290.0
#                                                    Michael Isvy               290.0
# src/main/java/org/springframework/samples/petcl... Gordon Dickens              79.0
#                                                    Michael Isvy                79.0
# src/main/java/org/springframework/samples/petcl... Antoine Rey                208.0
#                                                    Gordon Dickens             208.0
#                                                    Michael Isvy               208.0
# src/main/java/org/springframework/samples/petcl... Antoine Rey                 31.0
#                                                    Gordon Dickens              31.0
#                                                    Michael Isvy                31.0
# src/main/java/org/springframework/samples/petcl... Gordon Dickens              32.0
#                                                    Michael Isvy                32.0
# src/main/java/org/springframework/samples/petcl... Antoine Rey                130.0
#                                                    Gordon Dickens             130.0
#                                                    Michael Isvy               130.0
# src/main/java/org/springframework/samples/petcl... Antoine Rey                 62.0
#                                                    Gordon Dickens              62.0
#                                                    Michael Isvy                62.0
#                                                    Tomas Repel                 62.0
# src/main/java/org/springframework/samples/petcl... Gordon Dickens             201.0
# ...                                                                             ...
# src/main/java/org/springframework/samples/petcl... Gordon Dickens             194.0
#                                                    Michael Isvy               194.0
#                                                    Rossen Stoyanchev          194.0
# src/main/java/org/springframework/samples/petcl... Antoine Rey                  8.0
#                                                    Costin Leau                  8.0
# src/test/java/org/springframework/samples/petcl... Antoine Rey                 76.0
#                                                    Michael Isvy                76.0
# src/test/java/org/springframework/samples/petcl... Antoine Rey                388.0
#                                                    Attilio                    388.0
#                                                    Faisal Hameed              388.0
#                                                    Martin Klose               388.0
#                                                    Michael Isvy               388.0
# src/test/java/org/springframework/samples/petcl... Antoine Rey                 39.0
#                                                    Michael Isvy                39.0
# src/test/java/org/springframework/samples/petcl... Antoine Rey                 33.0
#                                                    Michael Isvy                33.0
# src/test/java/org/springframework/samples/petcl... Antoine Rey                 24.0
#                                                    Michael Isvy                24.0
# src/test/java/org/springframework/samples/petcl... Antoine Rey                 57.0
#                                                    Colin But                   57.0
# src/test/java/org/springframework/samples/petcl... Antoine Rey                192.0
#                                                    Colin But                  192.0
# src/test/java/org/springframework/samples/petcl... Antoine Rey                134.0
#                                                    Colin But                  134.0
# src/test/java/org/springframework/samples/petcl... Colin But                   76.0
# src/test/java/org/springframework/samples/petcl... Antoine Rey                116.0
#                                                    Colin But                  116.0
#                                                    Michael Isvy               116.0
# src/test/java/org/springframework/samples/petcl... Antoine Rey                 89.0
#                                                    Colin But                   89.0
#
#                                                                       length
# path                                               author
# src/main/java/org/springframework/samples/petcl... Antoine Rey         111.0
# src/main/java/org/springframework/samples/petcl... Antoine Rey          47.0
#                                                    Faisal Hameed        47.0
#                                                    Gordon Dickens       47.0
#                                                    Michael Isvy         47.0
#                                                    boly38               47.0
# src/main/java/org/springframework/samples/petcl... Antoine Rey          48.0
#                                                    Gordon Dickens       48.0
#                                                    Michael Isvy         48.0
# src/main/java/org/springframework/samples/petcl... Antoine Rey         153.0
#                                                    Gordon Dickens      153.0
#                                                    Michael Isvy        153.0
# src/main/java/org/springframework/samples/petcl... Gordon Dickens       56.0
#                                                    Michael Isvy         56.0
# src/main/java/org/springframework/samples/petcl... Antoine Rey         113.0
#                                                    Gordon Dickens      113.0
#                                                    Michael Isvy        113.0
# src/main/java/org/springframework/samples/petcl... Antoine Rey          29.0
#                                                    Gordon Dickens       29.0
#                                                    Michael Isvy         29.0
# src/main/java/org/springframework/samples/petcl... Gordon Dickens       30.0
#                                                    Michael Isvy         30.0
# src/main/java/org/springframework/samples/petcl... Antoine Rey          78.0
#                                                    Gordon Dickens       78.0
#                                                    Michael Isvy         78.0
# src/main/java/org/springframework/samples/petcl... Antoine Rey          43.0
#                                                    Gordon Dickens       43.0
#                                                    Michael Isvy         43.0
#                                                    Tomas Repel          43.0
# src/main/java/org/springframework/samples/petcl... Gordon Dickens      123.0
# ...                                                                      ...
# src/main/java/org/springframework/samples/petcl... Gordon Dickens       98.0
#                                                    Michael Isvy         98.0
#                                                    Rossen Stoyanchev    98.0
# src/main/java/org/springframework/samples/petcl... Antoine Rey           5.0
#                                                    Costin Leau           5.0
# src/test/java/org/springframework/samples/petcl... Antoine Rey          45.0
#                                                    Michael Isvy         45.0
# src/test/java/org/springframework/samples/petcl... Antoine Rey         204.0
#                                                    Attilio             204.0
#                                                    Faisal Hameed       204.0
#                                                    Martin Klose        204.0
#                                                    Michael Isvy        204.0
# src/test/java/org/springframework/samples/petcl... Antoine Rey          36.0
#                                                    Michael Isvy         36.0
# src/test/java/org/springframework/samples/petcl... Antoine Rey          22.0
#                                                    Michael Isvy         22.0
# src/test/java/org/springframework/samples/petcl... Antoine Rey          20.0
#                                                    Michael Isvy         20.0
# src/test/java/org/springframework/samples/petcl... Antoine Rey          52.0
#                                                    Colin But            52.0
# src/test/java/org/springframework/samples/petcl... Antoine Rey         185.0
#                                                    Colin But           185.0
# src/test/java/org/springframework/samples/petcl... Antoine Rey         125.0
#                                                    Colin But           125.0
# src/test/java/org/springframework/samples/petcl... Colin But            76.0
# src/test/java/org/springframework/samples/petcl... Antoine Rey          84.0
#                                                    Colin But            84.0
#                                                    Michael Isvy         84.0
# src/test/java/org/springframework/samples/petcl... Antoine Rey          83.0
#                                                    Colin But            83.0
#
# [163 rows x 3 columns]

# %%
grouped_commits['ownership'] = grouped_commits['additions'] / grouped_commits['additions_sum']
grouped_commits.head()
# Out:
#                                                                    additions  \
# path                                               author
# src/main/java/org/springframework/samples/petcl... Antoine Rey         111.0
# src/main/java/org/springframework/samples/petcl... Antoine Rey           3.0
#                                                    Faisal Hameed         1.0
#                                                    Gordon Dickens       14.0
#                                                    Michael Isvy         51.0
#
#                                                                    additions_sum  \
# path                                               author
# src/main/java/org/springframework/samples/petcl... Antoine Rey             111.0
# src/main/java/org/springframework/samples/petcl... Antoine Rey              70.0
#                                                    Faisal Hameed            70.0
#                                                    Gordon Dickens           70.0
#                                                    Michael Isvy             70.0
#
#                                                                    length  \
# path                                               author
# src/main/java/org/springframework/samples/petcl... Antoine Rey      111.0
# src/main/java/org/springframework/samples/petcl... Antoine Rey       47.0
#                                                    Faisal Hameed     47.0
#                                                    Gordon Dickens    47.0
#                                                    Michael Isvy      47.0
#
#                                                                    ownership
# path                                               author
# src/main/java/org/springframework/samples/petcl... Antoine Rey      1.000000
# src/main/java/org/springframework/samples/petcl... Antoine Rey      0.042857
#                                                    Faisal Hameed    0.014286
#                                                    Gordon Dickens   0.200000
#                                                    Michael Isvy     0.728571

# %%
ownership_hotspots = grouped_commits.reset_index().groupby(['author']).mean().sort_values(by='ownership', ascending=False)
ownership_hotspots.head(5)
# Out:
#                 additions  additions_sum      length  ownership
# author
# Colin But       85.000000     110.666667  100.833333   0.786699
# Michael Isvy    83.270833     121.979167   67.187500   0.749534
# Costin Leau     24.500000      48.000000   29.500000   0.732955
# Gordon Dickens  34.243243     136.594595   73.702703   0.216802
# Antoine Rey     15.755556     124.622222   72.422222   0.140097

# %%
ownerships = grouped_commits.reset_index().groupby(['path']).max()
ownerships.head(5)
# Out:
#                                                           author  additions  \
# path
# src/main/java/org/springframework/samples/petcl...   Antoine Rey      111.0
# src/main/java/org/springframework/samples/petcl...        boly38       51.0
# src/main/java/org/springframework/samples/petcl...  Michael Isvy       49.0
# src/main/java/org/springframework/samples/petcl...  Michael Isvy      164.0
# src/main/java/org/springframework/samples/petcl...  Michael Isvy       59.0
#
#                                                     additions_sum  length  \
# path
# src/main/java/org/springframework/samples/petcl...          111.0   111.0
# src/main/java/org/springframework/samples/petcl...           70.0    47.0
# src/main/java/org/springframework/samples/petcl...           67.0    48.0
# src/main/java/org/springframework/samples/petcl...          290.0   153.0
# src/main/java/org/springframework/samples/petcl...           79.0    56.0
#
#                                                     ownership
# path
# src/main/java/org/springframework/samples/petcl...   1.000000
# src/main/java/org/springframework/samples/petcl...   0.728571
# src/main/java/org/springframework/samples/petcl...   0.731343
# src/main/java/org/springframework/samples/petcl...   0.565517
# src/main/java/org/springframework/samples/petcl...   0.746835

# %%
plot_data = ownerships.reset_index()
plot_data['responsible']  = plot_data['author']
plot_data.loc[plot_data['ownership'] < 0.7, 'responsible']  = "None"
plot_data.head()
# Out:
#                                                 path        author  additions  \
# 0  src/main/java/org/springframework/samples/petc...   Antoine Rey      111.0
# 1  src/main/java/org/springframework/samples/petc...        boly38       51.0
# 2  src/main/java/org/springframework/samples/petc...  Michael Isvy       49.0
# 3  src/main/java/org/springframework/samples/petc...  Michael Isvy      164.0
# 4  src/main/java/org/springframework/samples/petc...  Michael Isvy       59.0
#
#    additions_sum  length  ownership   responsible
# 0          111.0   111.0   1.000000   Antoine Rey
# 1           70.0    47.0   0.728571        boly38
# 2           67.0    48.0   0.731343  Michael Isvy
# 3          290.0   153.0   0.565517          None
# 4           79.0    56.0   0.746835  Michael Isvy

# %%
import numpy as np
import matplotlib.cm as cm
import matplotlib.colors

authors = plot_data['author'].unique()

rgb_colors = [
                matplotlib.colors.rgb2hex(x) 
                for x in cm.RdYlGn_r(
                    np.linspace(0,1,len(authors)))
                ]

colors = plot_data[['author']].drop_duplicates()
colors['color'] = rgb_colors
colors
# Out:
#                author    color
# 0         Antoine Rey  #006837
# 1              boly38  #39a758
# 2        Michael Isvy  #9dd569
# 9         Tomas Repel  #e3f399
# 42        Tejas Metha  #fee999
# 44  Rossen Stoyanchev  #fca55d
# 45        Costin Leau  #e34933
# 51          Colin But  #a50026

# %%
colored_plot_data = pd.merge(plot_data, colors, left_on='responsible', right_on='author', how='left', suffixes=['', '_color'])
colored_plot_data.loc[colored_plot_data['responsible'] == 'None', 'color'] = "white"
colored_plot_data.head()
# Out:
#                                                 path        author  additions  \
# 0  src/main/java/org/springframework/samples/petc...   Antoine Rey      111.0
# 1  src/main/java/org/springframework/samples/petc...        boly38       51.0
# 2  src/main/java/org/springframework/samples/petc...  Michael Isvy       49.0
# 3  src/main/java/org/springframework/samples/petc...  Michael Isvy      164.0
# 4  src/main/java/org/springframework/samples/petc...  Michael Isvy       59.0
#
#    additions_sum  length  ownership   responsible  author_color    color
# 0          111.0   111.0   1.000000   Antoine Rey   Antoine Rey  #006837
# 1           70.0    47.0   0.728571        boly38        boly38  #39a758
# 2           67.0    48.0   0.731343  Michael Isvy  Michael Isvy  #9dd569
# 3          290.0   153.0   0.565517          None           NaN    white
# 4           79.0    56.0   0.746835  Michael Isvy  Michael Isvy  #9dd569

# %% [markdown]
# # Visualizing
# Export DataFrame into d3's flare format

# %%
import os
import json

def create_flare_json(data, json_file):
    
    json_data = {}
    json_data['name'] = 'flare'
    json_data['children'] = []
    
    for row in data.iterrows():
        series = row[1]
        path, filename = os.path.split(series['path'])

        last_children = None
        children = json_data['children']

        for path_part in path.split("/"):
            entry = None

            for child in children:
                if "name" in child and child["name"] == path_part:
                    entry = child
            if not entry:
                entry = {}
                children.append(entry)

            entry['name'] = path_part
            if not 'children' in entry: 
                entry['children'] = []

            children = entry['children']
            last_children = children

        last_children.append({
            'name' : filename + " [" + series['responsible'] + ", " + "{:6.2f}".format(series['ownership']) + "]",
            'weight' : series['ownership'],
            'size' :  series['length'],
            'author_color' : series['color']})

    with open (json_file, mode='w', encoding='utf-8') as json_file:
        json_file.write(json.dumps(json_data, indent=3))
        
create_flare_json(colored_plot_data, "vis/flare.json")

# %%
import IPython
url = "vis/knowledge_islands.html"
iframe = '<iframe src=' + url + ' scrolling="No" width="800" height="800" style=border:none;"></iframe>'
IPython.display.HTML(iframe)
# Out:
# <iframe src=vis/knowledge_islands.html scrolling="No" width="800" height="800" style=border:none;"></iframe>
